# %% [markdown]
# ### Setup and Data Loading

# %%
# Standard libraries
import pandas as pd
import matplotlib.pyplot as plt

# Scikit-learn
from sklearn import set_config
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder

# Config
set_config(transform_output='pandas')

# Reading Data
url = 'https://drive.google.com/file/d/1W0O7jh2BebbDPO0x4mnU3la5a1bIvCQZ/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
data = pd.read_csv(path)

# Defining X and y
X = data
y = X.pop('Expensive')

# Data splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3146)

# %% [markdown]
# ### Inspecting Data

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1168 entries, 179 to 507
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotArea        1168 non-null   int64
#  1   LotFrontage    967 non-null    float64
#  2   TotalBsmtSF    1168 non-null   int64
#  3   BedroomAbvGr   1168 non-null   int64
#  4   Fireplaces     1168 non-null   int64
#  5   PoolArea       1168 non-null   int64
#  6   GarageCars     1168 non-null   int64
#  7   WoodDeckSF     1168 non-null   int64
#  8   ScreenPorch    1168 non-null   int64
#  9   MSZoning       1168 non-null   object
#  10  Condition1     1168 non-null   object
#  11  Heating        1168 non-null   object
#  12  Street         1168 non-null   object
#  13  CentralAir     1168 non-null   object
#  14  Foundation     1168 non-null   object
#  15  ExterQual      1168 non-null   object
#  16  ExterCond      1168 non-null   object
#  17  BsmtQual       1138 non-null   object
#  18  BsmtCond       1138 non-null   object
#  19  BsmtExposure   1137 non-null   object
#  20  BsmtFinType1   1138 non-null   object
#  21  KitchenQual    1168 non-null   object
#  22  FireplaceQu    621 non-null    object
#  23  MSSubClass     1168 non-null   int64
#  24  OverallQual    1168 non-null   int64
#  25  OverallCond    1168 non-null   int64
#  26  YearBuilt      1168 non-null   int64
#  27  YearRemodAdd   1168 non-null   int64
#  28  MasVnrArea     1164 non-null   float64
#  29  BsmtFinSF1     1168 non-null   int64
#  30  BsmtFinSF2     1168 non-null   int64
#  31  BsmtUnfSF      1168 non-null   int64
#  32  1stFlrSF       1168 non-null   int64
#  33  2ndFlrSF       1168 non-null   int64
#  34  LowQualFinSF   1168 non-null   int64
#  35  GrLivArea      1168 non-null   int64
#  36  BsmtFullBath   1168 non-null   int64
#  37  BsmtHalfBath   1168 non-null   int64
#  38  FullBath       1168 non-null   int64
#  39  HalfBath       1168 non-null   int64
#  40  KitchenAbvGr   1168 non-null   int64
#  41  TotRmsAbvGrd   1168 non-null   int64
#  42  GarageYrBlt    1108 non-null   float64
#  43  GarageArea     1168 non-null   int64
#  44  OpenPorchSF    1168 non-null   int64
#  45  EnclosedPorch  1168 non-null   int64
#  46  3SsnPorch      1168 non-null   int64
#  47  MiscVal        1168 non-null   int64
#  48  MoSold         1168 non-null   int64
#  49  YrSold         1168 non-null   int64
#  50  Id             1168 non-null   int64
#  51  Alley          79 non-null     object
#  52  LotShape       1168 non-null   object
#  53  LandContour    1168 non-null   object
#  54  Utilities      1168 non-null   object
#  55  LotConfig      1168 non-null   object
#  56  LandSlope      1168 non-null   object
#  57  Neighborhood   1168 non-null   object
#  58  Condition2     1168 non-null   object
#  59  BldgType       1168 non-null   object
#  60  HouseStyle     1168 non-null   object
#  61  RoofStyle      1168 non-null   object
#  62  RoofMatl       1168 non-null   object
#  63  Exterior1st    1168 non-null   object
#  64  Exterior2nd    1168 non-null   object
#  65  MasVnrType     471 non-null    object
#  66  BsmtFinType2   1137 non-null   object
#  67  HeatingQC      1168 non-null   object
#  68  Electrical     1167 non-null   object
#  69  Functional     1168 non-null   object
#  70  GarageType     1108 non-null   object
#  71  GarageFinish   1108 non-null   object
#  72  GarageQual     1108 non-null   object
#  73  GarageCond     1108 non-null   object
#  74  PavedDrive     1168 non-null   object
#  75  PoolQC         5 non-null      object
#  76  Fence          227 non-null    object
#  77  MiscFeature    41 non-null     object
#  78  SaleType       1168 non-null   object
#  79  SaleCondition  1168 non-null   object
# dtypes: float64(3), int64(34), object(43)
# memory usage: 739.1+ KB

# %% [markdown]
# Objects / Strings:
# * Condition1
# * Heating
# * Street
# * CentralAir
# * Foundation

# %% [markdown]
# ### Automating Pipelines

# %% [markdown]
# Defining the branches

# %%
# 1. Select categorical and numerial column NAMES
X_cat_columns = X.select_dtypes(exclude='number').columns
X_num_columns = X.select_dtypes(include='number').columns

# 2. Create numerical pipeline
numeric_pipe = make_pipeline(
    SimpleImputer(strategy='mean')
)

# 3. Create categorical pipeline
categoric_pipe = make_pipeline(
    SimpleImputer(strategy='constant',
                  fill_value='N_A'),
    OneHotEncoder(sparse_output=False,
                  handle_unknown='ignore')
)

# %% [markdown]
# Creating the Preprocessor with `make_column_transformer`

# %%
preprocessor = make_column_transformer(
    (numeric_pipe, X_num_columns),
    (categoric_pipe, X_cat_columns)
)
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch'],
#       dtype='object')),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='N_A',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['MSZoning', 'Condition1', 'Heating', 'Street', 'CentralAir',
#        'Foundation'],
#       dtype='object'))])

# %% [markdown]
# Building the Full Pipeline

# %%
full_pipeline = make_pipeline(preprocessor,
                              DecisionTreeClassifier(random_state=42))

full_pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch'],
#       dtype='object')),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(fill_value='N_A',
#                                                                                  strategy='constant')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   Index(['MSZoning', 'Condition1', 'Heating', 'Street', 'CentralAir',
#        'Foundation'],
#       dtype='object'))])),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(random_state=42))])

# %% [markdown]
# Fit the X_train & y_train data with the pipeline

# %%
full_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch'],
#       dtype='object')),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(fill_value='N_A',
#                                                                                  strategy='constant')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   Index(['MSZoning', 'Condition1', 'Heating', 'Street', 'CentralAir',
#        'Foundation'],
#       dtype='object'))])),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(random_state=42))])

# %% [markdown]
# ### Using New Pipeline with `GridSearchCV`

# %%
# 1. Define parameter grid
param_grid = {
    'columntransformer__pipeline-1__simpleimputer__strategy': ['mean', 'median'],
    'decisiontreeclassifier__max_depth': range(2, 14, 2),
    'decisiontreeclassifier__min_samples_leaf': range(3, 20, 3)
}

# 2. Define GridSearchCV
search = GridSearchCV(full_pipeline,
                      param_grid,
                      cv=5,
                      verbose=1)

search.fit(X_train, y_train)

print(f'Best score: {search.best_score_:.4f}')
print('Best parameters found:')
print(search.best_params_)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best score: 0.9212
# Best parameters found:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean', 'decisiontreeclassifier__max_depth': 4, 'decisiontreeclassifier__min_samples_leaf': 9}

# %% [markdown]
# best cross-validation score:
# * `max_depth`of 4
# * `min_samples_leaf` of 9
# * `mean` strategy

# %% [markdown]
# ### Accuracy TEST set

# %%
y_pred = search.predict(X_test)
print(f'Test accuracy: {accuracy_score(y_test, y_pred):.4f}')
# Out:
# Test accuracy: 0.9041

# %% [markdown]
# ### BONUS: Inspecting Pipeline Steps

# %%
# Access the 'columntransformer' step
full_pipeline.named_steps.columntransformer
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch'],
#       dtype='object')),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='N_A',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['MSZoning', 'Condition1', 'Heating', 'Street', 'CentralAir',
#        'Foundation'],
#       dtype='object'))])

# %% [markdown]
# Going deeper! Beware of lower and upper case.

# %%
(
    full_pipeline
    .named_steps.columntransformer
    .named_transformers_['pipeline-2']
    .named_steps.onehotencoder
    .get_feature_names_out()
)
# Out:
# array(['MSZoning_C (all)', 'MSZoning_FV', 'MSZoning_RH', 'MSZoning_RL',
#        'MSZoning_RM', 'Condition1_Artery', 'Condition1_Feedr',
#        'Condition1_Norm', 'Condition1_PosA', 'Condition1_PosN',
#        'Condition1_RRAe', 'Condition1_RRAn', 'Condition1_RRNe',
#        'Condition1_RRNn', 'Heating_Floor', 'Heating_GasA', 'Heating_GasW',
#        'Heating_Grav', 'Heating_OthW', 'Heating_Wall', 'Street_Grvl',
#        'Street_Pave', 'CentralAir_N', 'CentralAir_Y', 'Foundation_BrkTil',
#        'Foundation_CBlock', 'Foundation_PConc', 'Foundation_Slab',
#        'Foundation_Stone', 'Foundation_Wood'], dtype=object)
