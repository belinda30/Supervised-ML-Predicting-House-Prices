# %% [markdown]
#  # THE ULTIMATIVE COMPETITION 🗣️

# %% [markdown]
# ### Import data and libraries

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import set_config
set_config(transform_output="pandas")

url = "https://drive.google.com/file/d/1L23SxwgqjdUeTKikW-L246yOcI12q0_D/view?usp=drive_link"
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
training_data = pd.read_csv(path)

# Setting the Index
training_data = training_data.set_index('Id')

# %% [markdown]
# ### Split data and train Models

# %%
# Separate label and split data for training and testing
y = training_data['Expensive'].copy()
X = training_data.drop('Expensive', axis=1).copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# Separate training data into numerical and text
X_num = X_train.select_dtypes(include='number')
X_cat = X_train.select_dtypes(exclude='number')

# Create Preprocessor and pipelines within it
preprocessor = ColumnTransformer(transformers=[
    ('num_pipe', make_pipeline(SimpleImputer(strategy='mean'),
                         StandardScaler()
                         ), X_num.columns),

    ('cat_pipe', make_pipeline(SimpleImputer(strategy='constant', fill_value='N_A'),
                         OneHotEncoder(handle_unknown='ignore', sparse_output=False)
                         ), X_cat.columns)
])

# %% [markdown]
# RandomForestClassifier

# %%
# Full Pipeline with RandomForestClassifier in it
forest_pipe = make_pipeline(preprocessor,
                            RandomForestClassifier(n_estimators=100,
                                                   random_state=42))

# Fitting the pipeline
forest_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'Yea...
#        'Neighborhood', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinType2',
#        'HeatingQC', 'Electrical', 'Functional', 'GarageType', 'GarageFinish',
# ...

# %% [markdown]
# GradientBoostingClassifier

# %%
# Full Pipeline with GradientBoostingClassifier in it
gradient_pipe = make_pipeline(preprocessor,
                            GradientBoostingClassifier(n_estimators=100,
                                                   random_state=42))

# Fitting the pipeline
gradient_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'Yea...
#        'Neighborhood', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinType2',
#        'HeatingQC', 'Electrical', 'Functional', 'GarageType', 'GarageFinish',
# ...

# %% [markdown]
# LogisticRegression

# %%
# Full Pipeline with LogisticRegression in it
logistic_pipe = make_pipeline(preprocessor,
                            LogisticRegression(random_state=42,
                                               max_iter=1000))

# Fitting the pipeline
logistic_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'Yea...
#        'Neighborhood', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinType2',
#        'HeatingQC', 'Electrical', 'Functional', 'GarageType', 'GarageFinish',
# ...

# %% [markdown]
# ### Assess performance

# %%
accuracy_score(y_true=y_test,
               y_pred=forest_pipe.predict(X_test))
# Out:
# 0.9657534246575342

# %%
accuracy_score(y_true=y_test,
               y_pred=gradient_pipe.predict(X_test))
# Out:
# 0.958904109589041

# %%
accuracy_score(y_true=y_test,
               y_pred=logistic_pipe.predict(X_test))
# Out:
# 0.9623287671232876

# %% [markdown]
# ### Finding the best parameters

# %%
# Define a function to perform a grid search, which helps to avoid duplicating code for different models
def run_grid_search(model, param_grid, X_train, y_train, preprocessor, cv=5, verbose=1):

  # Create a pipeline that first applies the data preprocessing steps, then fits the model
  pipe = make_pipeline(preprocessor, model)

  # GridSearchCV will test all possible combinations of parameters defined in 'param_grid'
  grid_search = GridSearchCV(pipe, param_grid, cv=cv, verbose=verbose)

  # Fit the model on the training data with the various parameter combinations
  grid_search.fit(X_train, y_train)

  # Return the trained GridSearchCV object, which hold the best parameters and model
  return grid_search

# ------ Function End

# %% [markdown]
# RandomForestClassifier Params

# %%
# Define a dictionary of hyperparameters to tune for the Random Forest model
rf_param_grid = {
    "columntransformer__num_pipe__simpleimputer__strategy": ["mean", "median"],
    'randomforestclassifier__n_estimators' :[100, 200, 300],
    "randomforestclassifier__max_depth": (None, 10, 20, 30),
    "randomforestclassifier__min_samples_leaf": (1, 2, 4)
}

# Run the grid search for the RandomForestClassifier using the specified parameters
rf_search = run_grid_search(
    RandomForestClassifier(random_state=1234),
    rf_param_grid,
    X_train,
    y_train,
    preprocessor
)

# Display the process
rf_search
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('num_pipe',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'O...
#        'MiscFeature', 'SaleType', 'SaleCondition'],
# ...

# %% [markdown]
# GradientBoostingClassifier

# %%
# Define a dictionary of hyperparameters to tune for the GradientBoostingClassifier model
gb_param_grid = {
    "columntransformer__num_pipe__simpleimputer__strategy": ["mean", "median"],
    "gradientboostingclassifier__n_estimators": [100, 200, 300],
    "gradientboostingclassifier__learning_rate": (0.05, 0.1, 0.2),
    "gradientboostingclassifier__max_depth": (3, 5, 7)
}

# Run the grid search for the GradientBoostingClassifier using the specified parameters
gb_search = run_grid_search(
    GradientBoostingClassifier(random_state=1234),
    gb_param_grid,
    X_train,
    y_train,
    preprocessor
)

# Display the process
gb_search
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('num_pipe',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'O...
#       dtype='object'))])),
# ...

# %% [markdown]
# LogisticRegression

# %%
# Define a dictionary of hyperparameters to tune for the LogisticRegression model
lr_param_grid = {
    "columntransformer__num_pipe__simpleimputer__strategy": ["mean", "median"],
    "logisticregression__C": (0.01, 0.1, 1, 10, 100),
    "logisticregression__max_iter": (1000, 2000)
}

# Run the grid search for the LogisticRegression using the specified parameters
lr_search = run_grid_search(
    LogisticRegression(random_state=1234),
    lr_param_grid,
    X_train,
    y_train,
    preprocessor
)

# Display the process
lr_search
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('num_pipe',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'O...
# ...

# %% [markdown]
# ### Evaluation Scores

# %%
# Function to get the scores for our model(s)
def evaluate_model(model, X_test, y_test):
  y_pred = model.predict(X_test)

  scores = {
      'Accuracy': accuracy_score(y_test, y_pred),
  }
  return scores
# ----------------- Function End

# Create an empty DataFrame to store model evaluation results
model_scores_df = pd.DataFrame(columns=[
    'Model', 'Accuracy'
])

# Evaluate the Random Forest model
rf_scores = evaluate_model(rf_search, X_test, y_test)
rf_scores['Model'] = 'Random Forest'

# Convert the dictionary to a Series matching the DataFrame columns, then assign as new row
model_scores_df.loc[len(model_scores_df)] = pd.Series(rf_scores, index=model_scores_df.columns)


# Evaluate the GradientBoosting model
gb_scores = evaluate_model(gb_search, X_test, y_test)
gb_scores['Model'] = 'Gradient Boosting'

# Convert the dictionary to a Series matching the DataFrame columns, then assign as new row
model_scores_df.loc[len(model_scores_df)] = pd.Series(gb_scores, index=model_scores_df.columns)


# Evaluate the LogisticRegression model
lr_scores = evaluate_model(lr_search, X_test, y_test)
lr_scores['Model'] = 'Logistic Regression'

# Convert the dictionary to a Series matching the DataFrame columns, then assign as new row
model_scores_df.loc[len(model_scores_df)] = pd.Series(lr_scores, index=model_scores_df.columns)


# Display the DataFrame
model_scores_df
# Out:
#                  Model  Accuracy
# 0        Random Forest  0.962329
# 1    Gradient Boosting  0.952055
# 2  Logistic Regression  0.969178

# %%
logistic_pipe.fit(X, y)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'Yea...
#        'Neighborhood', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinType2',
#        'HeatingQC', 'Electrical', 'Functional', 'GarageType', 'GarageFinish',
# ...

# %% [markdown]
# ### Predict on testing data

# %%
# Importing testing data
url = "https://drive.google.com/file/d/15PfmTxmavQCT-f7iY9tgwWxm9t4GRees/view?usp=drive_link"
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
testing_data = pd.read_csv(path)
testing_data = testing_data.set_index('Id')

# %%
# Predicting on my Logistic Regression model
lr_search.predict(testing_data)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(1459,))

# %%
# Saving the output as a Series
submission = pd.Series(lr_search.predict(testing_data), index=testing_data.index, name='Expensive')
submission
# Out:
# Id
# 1461    0
# 1462    0
# 1463    0
# 1464    0
# 1465    0
#        ..
# 2915    0
# 2916    0
# 2917    0
# 2918    0
# 2919    0
# Name: Expensive, Length: 1459, dtype: int64

# %%
# Exporting the Series as a csv file to create a submission file
submission.to_csv('./submission.csv')
